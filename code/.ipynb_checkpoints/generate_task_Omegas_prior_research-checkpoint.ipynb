# %%
import numpy as np
import pandas as pd
import random

# %%
## Read all files
df_prior_research = pd.read_csv('../data/prior_research.csv')
df_prior_research.theta.unique()
# Out:
# array([    184,     734,   10067,     198,     639,    9272, 3718691,
#             39,    2723, 7825200,   24901,   47184,      43,     236,
#             16,       7,       2,      49,      24,      25,      41,
#             63,     750,    4389,     278,     546,     819,    4700,
#            291,     246,     759,    4299,     268,     346,     729,
#           4000,     259,     550,    3218,     279,      61,      46,
#             74,      55,      59,      54,      26,      45,       4,
#            224,      14,      60,      15,     -46,     -27,    4486])

# %%
# Some useful function definitions

def w_star(n):
    w = 2*np.ones(n)/(3*n - 2)
    w[0] = n/(3*n - 2)
    return w

def w_cycle(n):
    w = np.ones(n)/n
    return w

def return_Ω(signals, truth, n_agents, n_samples):
    Ω = 0
    star_w = w_star(n_agents)
    cycle_w = w_cycle(n_agents)
    
    for i in range(n_samples):
        signal = np.asarray(random.choices(signals,k=n_agents))
        
        cycle_SAE = np.abs(cycle_w@signal - truth)
        star_SAE  = np.abs(star_w@signal - truth)
        
        if cycle_SAE > star_SAE:
            Ω+=1/n_samples
    return Ω

# %%
# Calculate Omega

n_samples = 10000
n_agents = 40

all_tasks = pd.DataFrame(columns=["task_id","study", "theta", "Omega_hat"])    

for idx,task_id in enumerate(df_prior_research['task_id'].unique()):
    df_temp = df_prior_research[df_prior_research['task_id']==task_id]
    
    signals = df_temp['pre_influence'].dropna().values
    theta = df_temp['pre_influence'].dropna().values[0]
    #print(theta)
    Omega_hat = return_Ω(signals, theta, n_agents, n_samples)
    
    all_tasks = all_tasks.append({
        "task_id": task_id,
        "study": df_temp['study'].dropna().values[0],
        "theta": theta,
        "Omega_hat": Omega_hat
    },ignore_index = True)

# %%
all_tasks
# Out:
# 0.8535999999999223

# %%
all_tasks.to_csv('../data/all_tasks_with_omega.csv',index=False)

# %%
pd.set_option('display.max_rows', None)
all_tasks.sort_values("Omega")
# Out:
#                  task       study        truth   Omega
# 51          Jayles_18  Jayles2020          700  0.2359
# 80        Gurcay_41.0      Gurcay           41  0.2431
# 7          Becker_246  Becker2017          246  0.2679
# 9         Becker_4299  Becker2017         4299  0.2691
# 50          Jayles_17  Jayles2020          200  0.2725
# 11         Becker_346  Becker2017          346  0.2835
# 83            Kao_139         Kao          139  0.3159
# 8          Becker_759  Becker2017          759  0.3219
# 79        Gurcay_25.0      Gurcay           25  0.3272
# 14         Becker_259  Becker2017          259  0.3355
# 48          Jayles_15  Jayles2020          240  0.3371
# 19          Becker_46  Becker2017           46  0.3397
# 17         Becker_279  Becker2017          279  0.3469
# 3          Becker_546  Becker2017          546  0.3495
# 13        Becker_4000  Becker2017         4000  0.3689
# 40           Jayles_7  Jayles2020     1.07e+07  0.3865
# 87     Becker2_2812.0  Becker2020         2812  0.4002
# 5         Becker_4700  Becker2017         4700  0.4009
# 46          Jayles_13  Jayles2020          100  0.4074
# 15         Becker_550  Becker2017          550  0.4074
# 77        Gurcay_49.5      Gurcay         49.5  0.4084
# 2          Becker_278  Becker2017          278  0.4100
# 1         Becker_4389  Becker2017         4389  0.4116
# 84            Kao_659         Kao          659  0.4121
# 6          Becker_291  Becker2017          291  0.4144
# 0          Becker_750  Becker2017          750  0.4266
# 27          Becker_41  Becker2017           41  0.4473
# 24          Becker_54  Becker2017           54  0.4577
# 85           Kao_5897         Kao         5897  0.4596
# 12         Becker_729  Becker2017          729  0.4617
# 90       Becker2_29.6  Becker2020         29.6  0.4654
# 22          Becker_59  Becker2017           59  0.4658
# 26          Becker_45  Becker2017           45  0.4682
# 18          Becker_61  Becker2017           61  0.4711
# 81        Gurcay_63.0      Gurcay           63  0.4824
# 73       Gurcay_236.0      Gurcay          236  0.4825
# 21          Becker_55  Becker2017           55  0.4837
# 94     Becker2_1501.0  Becker2020         1501  0.4854
# 93      Becker2_609.0  Becker2020          609  0.4870
# 25          Becker_26  Becker2017           26  0.4882
# 78        Gurcay_24.9      Gurcay         24.9  0.4989
# 91    Becker2_30000.0  Becker2020        30000  0.5094
# 96     Becker2_7912.0  Becker2020         7912  0.5281
# 10         Becker_268  Becker2017          268  0.5318
# 74        Gurcay_16.4      Gurcay         16.4  0.5352
# 41           Jayles_8  Jayles2020      2.3e+07  0.5377
# 75        Gurcay_7.08      Gurcay         7.08  0.5525
# 82             Kao_54         Kao           54  0.5718
# 4          Becker_819  Becker2017          819  0.5720
# 49          Jayles_16  Jayles2020          480  0.5768
# 20          Becker_74  Becker2017           74  0.5769
# 16        Becker_3218  Becker2017         3218  0.5771
# 92   Becker2_142770.0  Becker2020       142770  0.5988
# 23          Becker_39  Becker2017           39  0.6072
# 69   Gurcay_7825200.0      Gurcay   7.8252e+06  0.6218
# 32         Lorenz_639      Lorenz          639  0.6359
# 88      Becker2_570.0  Becker2020          570  0.6454
# 89       Becker2_10.0  Becker2020           10  0.6565
# 36           Jayles_3  Jayles2020      2.6e+07  0.6642
# 95       Becker2_41.0  Becker2020           41  0.6733
# 64          Jayles_31  Jayles2020        5e+06  0.6821
# 38           Jayles_5  Jayles2020      6.5e+06  0.6861
# 58          Jayles_25  Jayles2020      1.6e+06  0.6933
# 76         Gurcay_2.7      Gurcay          2.7  0.6935
# 47          Jayles_14  Jayles2020          450  0.6990
# 43          Jayles_10  Jayles2020      2.2e+07  0.7178
# 29         Lorenz_734      Lorenz          734  0.7317
# 72        Gurcay_43.0      Gurcay           43  0.7402
# 37           Jayles_4  Jayles2020      2.1e+07  0.7404
# 60          Jayles_27  Jayles2020          720  0.7415
# 63          Jayles_30  Jayles2020       129000  0.7495
# 39           Jayles_6  Jayles2020      4.5e+06  0.7610
# 30       Lorenz_10067      Lorenz        10067  0.7625
# 45          Jayles_12  Jayles2020       110000  0.7647
# 86          Kao_27852         Kao        27852  0.7768
# 67       Gurcay_39.52      Gurcay        39.52  0.7778
# 34           Jayles_1  Jayles2020      3.8e+07  0.7793
# 31         Lorenz_198      Lorenz          198  0.8112
# 44          Jayles_11  Jayles2020        40000  0.8249
# 71     Gurcay_47184.0      Gurcay        47184  0.8251
# 42           Jayles_9  Jayles2020      1.5e+07  0.8282
# 28         Lorenz_184      Lorenz          184  0.8491
# 68      Gurcay_2723.0      Gurcay         2723  0.8571
# 35           Jayles_2  Jayles2020      2.5e+07  0.8606
# 33        Lorenz_9272      Lorenz         9272  0.8646
# 66   Gurcay_3718691.0      Gurcay  3.71869e+06  0.8790
# 59          Jayles_26  Jayles2020       600000  0.8893
# 62          Jayles_29  Jayles2020     5.78e+07  0.9068
# 61          Jayles_28  Jayles2020      1.4e+06  0.9155
# 65          Jayles_32  Jayles2020      1.5e+06  0.9213
# 54          Jayles_21  Jayles2020       235000  0.9257
# 52          Jayles_19  Jayles2020       695700  0.9386
# 53          Jayles_20  Jayles2020       385000  0.9391
# 57          Jayles_24  Jayles2020       100000  0.9441
# 70  Gurcay_24901.4611      Gurcay      24901.5  0.9483
# 56          Jayles_23  Jayles2020       100000  0.9500
# 55          Jayles_22  Jayles2020         9461  0.9544

# %%
df_temp['study']
# Out:
# 0      lorenz2011
# 1      lorenz2011
# 2      lorenz2011
# 3      lorenz2011
# 4      lorenz2011
#           ...
# 799    lorenz2011
# 800    lorenz2011
# 801    lorenz2011
# 802    lorenz2011
# 803    lorenz2011
# Name: study, Length: 144, dtype: object
