# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from scipy.special import erf
warnings.filterwarnings('ignore')
sns.set(style="white", context="talk")

np.random.seed(42)

# %%
df_tasks = pd.read_csv('../data/empirical_data/prior_tasks_with_omega.csv')

# %%
df_tasks
# Out:
#                     task_id       study   theta  Omega_hat     omega  \
# 0       lorenz2017_task_184  lorenz2011   430.0     0.4923  0.100000
# 1       lorenz2017_task_184  lorenz2011   430.0     0.6502  0.100000
# 2       lorenz2017_task_184  lorenz2011   430.0     0.7395  0.100000
# 3       lorenz2017_task_184  lorenz2011   430.0     0.8005  0.100000
# 4       lorenz2017_task_184  lorenz2011   430.0     0.4631  0.333333
# ..                      ...         ...     ...        ...       ...
# 907  df_becker2019_Soldiers  becker2019  5000.0     0.8499  0.666667
# 908  df_becker2019_Soldiers  becker2019  5000.0     0.4832  1.000000
# 909  df_becker2019_Soldiers  becker2019  5000.0     0.6775  1.000000
# 910  df_becker2019_Soldiers  becker2019  5000.0     0.7721  1.000000
# 911  df_becker2019_Soldiers  becker2019  5000.0     0.8320  1.000000
#
#      n_agents  omega_as_frac
# 0           5           0.10
# 1          20           0.10
# 2          35           0.10
# 3          50           0.10
# 4           5           0.33
# ..        ...            ...
# 907        50           0.66
# 908         5           1.00
# 909        20           1.00
# 910        35           1.00
# 911        50           1.00
#
# [912 rows x 7 columns]

# %%
p1 = sns.relplot(x="n_agents", y="Omega_hat",
            hue='task_id',
            col="study",
            row='omega_as_frac',
            height=5,facet_kws=dict(sharex=False),
            kind="line", legend=None, data=df_tasks)

for axes in p1.axes:
    for ax in axes:
        ax.set_xlim(1,50)
        ax.xaxis.set_ticks(np.arange(0, 55, 10))
        ax.set_ylim(0,1.05)
        ax.tick_params(labelsize=25)
        ax.set_xlabel(r"$n$",fontsize=30)
        ax.set_ylabel("Ω",fontsize=30)
        #ax.set_title("")
    
#plt.savefig('./empirical_robust_omega.pdf', bbox_inches='tight')

# %%
# Out:
# array([ 0, 10, 20, 30, 40, 50])
