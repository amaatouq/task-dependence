# %%
import pandas as pd
import numpy as np
import math
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../data/prior_research.csv')
data['group_task'] = data['group_id'].astype(str)+'_'+data['task_id'].astype(str)
data
# Out:
#             study  influence            group_id  theta  pre_influence  \
# 0      lorenz2011          0         081111_1557    184          430.0
# 1      lorenz2011          0         081111_1557    184          520.0
# 2      lorenz2011          0         081111_1557    184           50.0
# 3      lorenz2011          0         081111_1557    184           15.0
# 4      lorenz2011          0         081111_1557    184         1750.0
# ...           ...        ...                 ...    ...            ...
# 20025  becker2019          1  C_3_Social_2_Repub   4486         2000.0
# 20026  becker2019          1  C_3_Social_2_Repub   4486       250000.0
# 20027  becker2019          1  C_3_Social_2_Repub    -46           70.0
# 20028  becker2019          1  C_3_Social_2_Repub     15           20.0
# 20029  becker2019          1  C_3_Social_2_Repub    -46           10.0
#
#        post_influence               subject_id                     task_id  \
# 0               422.0            1_081111_1557         lorenz2017_task_184
# 1                22.0            2_081111_1557         lorenz2017_task_184
# 2                 4.0            3_081111_1557         lorenz2017_task_184
# 3                10.0            4_081111_1557         lorenz2017_task_184
# 4              1650.0            5_081111_1557         lorenz2017_task_184
# ...               ...                      ...                         ...
# 20025          2000.0  1085_C_3_Social_2_Repub      df_becker2019_Soldiers
# 20026         14000.0  1100_C_3_Social_2_Repub      df_becker2019_Soldiers
# 20027             NaN  1100_C_3_Social_2_Repub  df_becker2019_Unemployment
# 20028            16.0  1111_C_3_Social_2_Repub      df_becker2019_Military
# 20029            10.0  1085_C_3_Social_2_Repub  df_becker2019_Unemployment
#
#       original_condition                                     group_task
# 0                   Solo                081111_1557_lorenz2017_task_184
# 1                   Solo                081111_1557_lorenz2017_task_184
# 2                   Solo                081111_1557_lorenz2017_task_184
# 3                   Solo                081111_1557_lorenz2017_task_184
# 4                   Solo                081111_1557_lorenz2017_task_184
# ...                  ...                                            ...
# 20025             Social      C_3_Social_2_Repub_df_becker2019_Soldiers
# 20026             Social      C_3_Social_2_Repub_df_becker2019_Soldiers
# 20027             Social  C_3_Social_2_Repub_df_becker2019_Unemployment
# 20028             Social      C_3_Social_2_Repub_df_becker2019_Military
# 20029             Social  C_3_Social_2_Repub_df_becker2019_Unemployment
#
# [20030 rows x 10 columns]

# %% [markdown]
# # getting the task big Omega

# %%
df_tasks = pd.read_csv('../data/prior_tasks_with_omega.csv')
tasks = df_tasks.set_index('task_id')
tasks.sort_values('theta')
tasks = tasks.to_dict(orient='index')
tasks
# Out:
# {'lorenz2017_task_184': {'study': 'lorenz2011',
#   'theta': 430.0,
#   'Omega_hat': 0.7348999999999354},
#  'lorenz2017_task_734': {'study': 'lorenz2011',
#   'theta': 350.0,
#   'Omega_hat': 0.8643999999999211},
#  'lorenz2017_task_10067': {'study': 'lorenz2011',
#   'theta': 12000.0,
#   'Omega_hat': 0.7387999999999351},
#  'lorenz2017_task_198': {'study': 'lorenz2011',
#   'theta': 92.0,
#   'Omega_hat': 0.8062999999999275},
#  'lorenz2017_task_639': {'study': 'lorenz2011',
#   'theta': 98.0,
#   'Omega_hat': 0.810699999999927},
#  'lorenz2017_task_9272': {'study': 'lorenz2011',
#   'theta': 806.0,
#   'Omega_hat': 0.8846999999999189},
#  'gurcay2015_task_1_3718691.0': {'study': 'gurcay2015',
#   'theta': 1000000.0,
#   'Omega_hat': 0.9008999999999172},
#  'gurcay2015_task_2_39.52': {'study': 'gurcay2015',
#   'theta': 15.0,
#   'Omega_hat': 0.8431999999999235},
#  'gurcay2015_task_3_2723.0': {'study': 'gurcay2015',
#   'theta': 1050.0,
#   'Omega_hat': 0.8752999999999199},
#  'gurcay2015_task_4_7825200.0': {'study': 'gurcay2015',
#   'theta': 5000000.0,
#   'Omega_hat': 0.765299999999932},
#  'gurcay2015_task_5_24901.4611': {'study': 'gurcay2015',
#   'theta': 2048.0,
#   'Omega_hat': 0.9489999999999118},
#  'gurcay2015_task_6_47184.0': {'study': 'gurcay2015',
#   'theta': 28000.0,
#   'Omega_hat': 0.8497999999999227},
#  'gurcay2015_task_7_43.0': {'study': 'gurcay2015',
#   'theta': 50.0,
#   'Omega_hat': 0.7261999999999363},
#  'gurcay2015_task_8_236.0': {'study': 'gurcay2015',
#   'theta': 200.0,
#   'Omega_hat': 0.6492999999999448},
#  'gurcay2015_task_9_16.4': {'study': 'gurcay2015',
#   'theta': 20.0,
#   'Omega_hat': 0.5279999999999582},
#  'gurcay2015_task_10_7.08': {'study': 'gurcay2015',
#   'theta': 20.0,
#   'Omega_hat': 0.4412999999999677},
#  'gurcay2015_task_11_2.7': {'study': 'gurcay2015',
#   'theta': 5.0,
#   'Omega_hat': 0.4340999999999685},
#  'gurcay2015_task_12_49.5': {'study': 'gurcay2015',
#   'theta': 35.0,
#   'Omega_hat': 0.4047999999999717},
#  'gurcay2015_task_13_24.9': {'study': 'gurcay2015',
#   'theta': 9.0,
#   'Omega_hat': 0.5813999999999523},
#  'gurcay2015_task_14_25.0': {'study': 'gurcay2015',
#   'theta': 30.0,
#   'Omega_hat': 0.3741999999999751},
#  'gurcay2015_task_15_41.0': {'study': 'gurcay2015',
#   'theta': 41.0,
#   'Omega_hat': 0.24409999999998944},
#  'gurcay2015_task_16_63.0': {'study': 'gurcay2015',
#   'theta': 60.0,
#   'Omega_hat': 0.4857999999999628},
#  'df_becker2017_750': {'study': 'becker2017',
#   'theta': 600.0,
#   'Omega_hat': 0.2683999999999868},
#  'df_becker2017_4389': {'study': 'becker2017',
#   'theta': 3000.0,
#   'Omega_hat': 0.36029999999997664},
#  'df_becker2017_278': {'study': 'becker2017',
#   'theta': 300.0,
#   'Omega_hat': 0.31369999999998177},
#  'df_becker2017_546': {'study': 'becker2017',
#   'theta': 350.0,
#   'Omega_hat': 0.5377999999999571},
#  'df_becker2017_819': {'study': 'becker2017',
#   'theta': 440.0,
#   'Omega_hat': 0.5834999999999521},
#  'df_becker2017_4700': {'study': 'becker2017',
#   'theta': 1050.0,
#   'Omega_hat': 0.5950999999999508},
#  'df_becker2017_291': {'study': 'becker2017',
#   'theta': 250.0,
#   'Omega_hat': 0.3923999999999731},
#  'df_becker2017_246': {'study': 'becker2017',
#   'theta': 200.0,
#   'Omega_hat': 0.5127999999999598},
#  'df_becker2017_759': {'study': 'becker2017',
#   'theta': 500.0,
#   'Omega_hat': 0.6279999999999472},
#  'df_becker2017_4299': {'study': 'becker2017',
#   'theta': 2476.0,
#   'Omega_hat': 0.3501999999999777},
#  'df_becker2017_268': {'study': 'becker2017',
#   'theta': 48.0,
#   'Omega_hat': 0.7465999999999341},
#  'df_becker2017_346': {'study': 'becker2017',
#   'theta': 200.0,
#   'Omega_hat': 0.6410999999999457},
#  'df_becker2017_729': {'study': 'becker2017',
#   'theta': 280.0,
#   'Omega_hat': 0.5422999999999566},
#  'df_becker2017_4000': {'study': 'becker2017',
#   'theta': 5500.0,
#   'Omega_hat': 0.3533999999999774},
#  'df_becker2017_259': {'study': 'becker2017',
#   'theta': 264.0,
#   'Omega_hat': 0.3264999999999804},
#  'df_becker2017_550': {'study': 'becker2017',
#   'theta': 150.0,
#   'Omega_hat': 0.5911999999999512},
#  'df_becker2017_3218': {'study': 'becker2017',
#   'theta': 4100.0,
#   'Omega_hat': 0.27739999999998577},
#  'df_becker2017_279': {'study': 'becker2017',
#   'theta': 460.0,
#   'Omega_hat': 0.3285999999999801},
#  'df_becker2017_61': {'study': 'becker2017',
#   'theta': 55.0,
#   'Omega_hat': 0.3883999999999736},
#  'df_becker2017_46': {'study': 'becker2017',
#   'theta': 80.0,
#   'Omega_hat': 0.4912999999999622},
#  'df_becker2017_74': {'study': 'becker2017',
#   'theta': 70.0,
#   'Omega_hat': 0.5552999999999552},
#  'df_becker2017_55': {'study': 'becker2017',
#   'theta': 50.0,
#   'Omega_hat': 0.3618999999999765},
#  'df_becker2017_59': {'study': 'becker2017',
#   'theta': 60.0,
#   'Omega_hat': 0.4537999999999664},
#  'df_becker2017_39': {'study': 'becker2017',
#   'theta': 40.0,
#   'Omega_hat': 0.6149999999999486},
#  'df_becker2017_54': {'study': 'becker2017',
#   'theta': 50.0,
#   'Omega_hat': 0.439099999999968},
#  'df_becker2017_26': {'study': 'becker2017',
#   'theta': 45.0,
#   'Omega_hat': 0.5037999999999608},
#  'df_becker2017_45': {'study': 'becker2017',
#   'theta': 50.0,
#   'Omega_hat': 0.3730999999999752},
#  'df_becker2017_41': {'study': 'becker2017',
#   'theta': 60.0,
#   'Omega_hat': 0.37519999999997494},
#  'df_becker2019_Unemployment': {'study': 'becker2019',
#   'theta': 4.7,
#   'Omega_hat': 0.5601999999999546},
#  'df_becker2019_Election': {'study': 'becker2019',
#   'theta': 250.0,
#   'Omega_hat': 0.5528999999999554},
#  'df_becker2019_Taxes': {'study': 'becker2019',
#   'theta': 15.0,
#   'Omega_hat': 0.5866999999999517},
#  'df_becker2019_California': {'study': 'becker2019',
#   'theta': 67.0,
#   'Omega_hat': 0.5158999999999595},
#  'df_becker2019_Military': {'study': 'becker2019',
#   'theta': 25.0,
#   'Omega_hat': 0.69309999999994},
#  'df_becker2019_Immigration': {'study': 'becker2019',
#   'theta': 25.0,
#   'Omega_hat': 0.7176999999999373},
#  'df_becker2019_Soldiers': {'study': 'becker2019',
#   'theta': 5000.0,
#   'Omega_hat': 0.8527999999999224}}

# %%
#Computing the group stuff
group_data = []
for group in data.group_task.unique():
    game_data = {}
    temp_data = data[(data.group_task==group)]
    
    if not temp_data.empty:
        task_id = np.array(temp_data.task_id)[0]
        influence = np.array(temp_data.influence)[0]
        n = temp_data.shape[0]
        truth = tasks[task_id]['theta']

        revised_woc = temp_data.post_influence.mean()
        initial_woc = temp_data.pre_influence.mean()
        

        game_data = {'group_task':group,
                     'group_id': np.array(temp_data.group_id)[0],
                     'group_size':n,
                     'Omega_hat': tasks[task_id]['Omega_hat'],

                     'task_id': task_id,
                     'revised_woc':revised_woc,
                     'initial_woc':initial_woc,
                     'influence':influence,
                     'dataset': np.array(temp_data.study)[0],
                     'theta': truth,
                     
                     'revised_mse': (truth - revised_woc)**2,
                     'initial_mse': (truth - initial_woc)**2,

                     'revised_abs_error': np.abs(truth - revised_woc),
                     'initial_abs_error': np.abs(truth - initial_woc),
                                     }

        group_data.append(game_data)    
df_group_data = pd.DataFrame(group_data)
zscore = lambda x: (x - x.mean()) / x.std()

df_group_data['revised_mse_zscore'] = df_group_data.groupby('task_id')['revised_mse'].transform(zscore)
df_group_data['initial_mse_zscore'] = df_group_data.groupby('task_id')['initial_mse'].transform(zscore)

df_group_data['revised_abs_error_zscore'] = df_group_data.groupby('task_id')['revised_abs_error'].transform(zscore)
df_group_data['initial_abs_error_zscore'] = df_group_data.groupby('task_id')['initial_abs_error'].transform(zscore)


df_group_data['improved'] = df_group_data['initial_abs_error'] > df_group_data['revised_abs_error']
#df_group_data

# %%
df_group_data.to_csv('../data/prior_research_group.csv',index=False)
